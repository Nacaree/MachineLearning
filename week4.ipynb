# %%
class Book:
    def __init__(self, title="Unknown Title", author="Unknown Author", isBorrowed=False):
        self.title = title
        self.author = author
        self.isBorrowed = isBorrowed

    def borrowBook(self):
        if self.isBorrowed:
            print("Book is already borrowed.")
        else:
            self.isBorrowed = True
            print("Book borrowed successfully.")

    def returnBook(self):
        if not self.isBorrowed:
            print("Book is already returned.")
        else:
            self.isBorrowed = False
            print("Book returned successfully.")

    def displayStatus(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("Borrowed:", self.isBorrowed)


# ===== Library Management System =====
print("===== Library Management System =====")

title = input("Enter Book Title: ")
author = input("Enter Book Author: ")

book1 = Book(title, author, False)
book1.displayStatus()
print("----------------")

book1.borrowBook()
book1.displayStatus()
print("----------------")

book1.borrowBook()
print("----------------")

book1.returnBook()
book1.displayStatus()
# Out:
# ===== Library Management System =====
# Title: 48 laws of power
# Author: John Green
# Borrowed: False
# ----------------
# Book borrowed successfully.
# Title: 48 laws of power
# Author: John Green
# Borrowed: True
# ----------------
# Book is already borrowed.
# ----------------
# Book returned successfully.
# Title: 48 laws of power
# Author: John Green
# Borrowed: False

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited: {amount}")
        self.show_balance()

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance.")
        else:
            self.balance -= amount
            print(f"Withdrew: {amount}")
            self.show_balance()

    def show_balance(self):
        print("Account Number:", self.account_number)
        print("Balance:", self.balance)


class SavingsAccount(Account):
    def __init__(self, account_number, balance=0, interest_rate=0):
        super().__init__(account_number, balance)
        self.interest_rate = interest_rate

    def add_interest(self):
        interest = self.balance * (self.interest_rate / 100)
        new_balance = self.balance + interest
        self.balance = new_balance
        print(f"Interest added: {interest}")
        self.show_balance()


# ===== Smart Banking System =====
print("===== Smart Banking System =====")

acc1 = SavingsAccount("SA001", 1000, 5)
acc1.show_balance()
print("----------------")

acc1.deposit(500)
print("----------------")

acc1.withdraw(300)
print("----------------")

acc1.add_interest()
print("----------------")

acc1.withdraw(10000)
# Out:
# ===== Smart Banking System =====
# Account Number: SA001
# Balance: 1000
# ----------------
# Deposited: 500
# Account Number: SA001
# Balance: 1500
# ----------------
# Withdrew: 300
# Account Number: SA001
# Balance: 1200
# ----------------
# Interest added: 60.0
# Account Number: SA001
# Balance: 1260.0
# ----------------
# Insufficient balance.
